# %% [markdown]
# # Intel Image Classification (CNN - Keras)

# %% [markdown]
# # Import Packages

# %%
import numpy as np
import os
from sklearn.metrics import confusion_matrix
import seaborn as sn; sn.set(font_scale=1.4)
from sklearn.utils import shuffle           
import matplotlib.pyplot as plt             
import cv2                                 
import tensorflow as tf                
from tqdm import tqdm

# %%
class_names = ['mountain', 'street', 'glacier', 'buildings', 'sea', 'forest']
class_names_label = {class_name:i for i, class_name in enumerate(class_names)}

nb_classes = len(class_names)

IMAGE_SIZE = (32, 32)

# %% [markdown]
# # Loading the Data
# We have to write a load_data function that load the images and the labels from the folder.

# %%
def load_data():
    """
        Load the data:
            - 14,034 images to train the network.
            - 3,000 images to evaluate how accurately the network learned to classify images.
    """
    
    #datasets = ['C:/Users/Daney/Desktop/intel_classif/seg_train/seg_train',
    #            'C:/Users/Daney/Desktop/intel_classif/seg_test/seg_test']
    
    datasets = ['./seg_train',
                './seg_test']
    output = []
    
    # Iterate through training and test sets
    for dataset in datasets:
        
        images = []
        labels = []
        
        print("Loading {}".format(dataset))
        
        # Iterate through each folder corresponding to a category
        for folder in os.listdir(dataset):
            label = class_names_label[folder]
            
            # Iterate through each image in our folder. tqdm is a widget in output...
            for file in tqdm(os.listdir(os.path.join(dataset, folder))):
                
                # Get the path name of the image
                img_path = os.path.join(os.path.join(dataset, folder), file)
                
                # Open and resize the img
                image = cv2.imread(img_path)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                image = cv2.resize(image, IMAGE_SIZE) 
                
                # Append the image and its corresponding label to the output
                images.append(image)
                labels.append(label)
                
        images = np.array(images, dtype = 'float32')
        labels = np.array(labels, dtype = 'int32')   
        
        output.append((images, labels))

    return output

# %%
(train_images, train_labels), (test_images, test_labels) = load_data()
# Out:
#   0%|          | 9/2191 [00:00<00:26, 82.71it/s]
# Loading ./seg_train
# 100%|██████████| 2191/2191 [00:12<00:00, 180.33it/s]
# 100%|██████████| 2271/2271 [00:13<00:00, 162.89it/s]
# 100%|██████████| 2404/2404 [00:15<00:00, 153.28it/s]
# 100%|██████████| 2512/2512 [00:15<00:00, 157.01it/s]
# 100%|██████████| 2274/2274 [00:14<00:00, 152.70it/s]
# 100%|██████████| 2382/2382 [00:15<00:00, 152.21it/s]
#   4%|▍         | 17/437 [00:00<00:02, 163.43it/s]
# Loading ./seg_test
# 100%|██████████| 437/437 [00:03<00:00, 137.76it/s]
# 100%|██████████| 474/474 [00:03<00:00, 154.83it/s]
# 100%|██████████| 553/553 [00:03<00:00, 167.23it/s]
# 100%|██████████| 525/525 [00:04<00:00, 127.40it/s]
# 100%|██████████| 510/510 [00:03<00:00, 163.70it/s]
# 100%|██████████| 501/501 [00:03<00:00, 151.82it/s]

# %%
train_images, train_labels = shuffle(train_images, train_labels, random_state=42)

# %% [markdown]
# # Let's explore the dataset

# %%
n_train = train_labels.shape[0]
n_test = test_labels.shape[0]

print ("Number of training examples: {}".format(n_train))
print ("Number of testing examples: {}".format(n_test))
print ("Each image is of size: {}".format(IMAGE_SIZE))
# Out:
# Number of training examples: 14034
# Number of testing examples: 3000
# Each image is of size: (32, 32)

# %%
import pandas as pd

_, train_counts = np.unique(train_labels, return_counts=True)
_, test_counts = np.unique(test_labels, return_counts=True)
pd.DataFrame({'train': train_counts,
                    'test': test_counts}, 
             index=class_names
            ).plot.bar()
plt.show()

# %%
plt.pie(train_counts,
        explode=(0, 0, 0, 0, 0, 0) , 
        labels=class_names,
        autopct='%1.1f%%')
plt.axis('equal')
plt.title('Proportion of each observed category')
plt.show()

# %% [markdown]
# ## Good practice: scale the data

# %%
train_images = train_images / 255.0 
test_images = test_images / 255.0

# %% [markdown]
# ## Visualize the data
# We can display a random image from the training set.

# %%
def display_random_image(class_names, images, labels):
    """
        Display a random image from the images array and its correspond label from the labels array.
    """
    
    index = np.random.randint(images.shape[0])
    plt.figure()
    plt.imshow(images[index])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title('Image #{} : '.format(index) + class_names[labels[index]])
    plt.show()

# %%
display_random_image(class_names, train_images, train_labels)

# %% [markdown]
# We can also display the first 25 images from the training set directly with a loop to get a better view

# %%
def display_examples(class_names, images, labels):
    """
        Display 25 images from the images array with its corresponding labels
    """
    
    fig = plt.figure(figsize=(10,10))
    fig.suptitle("Some examples of images of the dataset", fontsize=16)
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)
        plt.xlabel(class_names[labels[i]])
    plt.show()

# %%
display_examples(class_names, train_images, train_labels)

# %% [markdown]
# # Beginner: Simple Model Creation
#
# Steps are:
# 1. Build the model,
# 1. Compile the model,
# 1. Train / fit the data to the model,
# 1. Evaluate the model on the testing set,
# 1. Carry out an error analysis of our model.
#
# We can build an easy model composed of different layers such as:
# * Conv2D: (32 filters of size 3 by 3) The features will be "extracted" from the image.
# * MaxPooling2D: The images get half sized.
# * Flatten: Transforms the format of the images from a 2d-array to a 1d-array of 150 150 3 pixel values.
# * Relu  : given a value x, returns max(x, 0).
# * Softmax: 6 neurons, probability that the image belongs to one of the classes.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu', input_shape = (IMAGE_SIZE[0], IMAGE_SIZE[1], 3)), 
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(6, activation=tf.nn.softmax)
])

# %% [markdown]
# Then, we can compile it with some parameters such as:
# * **Optimizer**: adam = RMSProp + Momentum.
# What is Momentum and RMSProp ?
# * Momentum = takes into account past gradient to have a better update.
# * RMSProp = exponentially weighted average of the squares of past gradients.
# * **Loss function**: we use sparse categorical crossentropy for classification, each images belongs to one class only

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# We fit the model to the data from the training set. The neural network will learn by itself the pattern in order to distinguish each category.

# %%
history = model.fit(train_images, train_labels, batch_size=128, epochs=10, validation_split = 0.2)
# Out:
# Epoch 1/10
# 88/88 [==============================] - 6s 62ms/step - loss: 1.4082 - accuracy: 0.4335 - val_loss: 0.9716 - val_accuracy: 0.6388
# Epoch 2/10
# 88/88 [==============================] - 5s 53ms/step - loss: 0.9472 - accuracy: 0.6560 - val_loss: 0.8769 - val_accuracy: 0.6587
# Epoch 3/10
# 88/88 [==============================] - 6s 67ms/step - loss: 0.8586 - accuracy: 0.6826 - val_loss: 0.8078 - val_accuracy: 0.6933
# Epoch 4/10
# 88/88 [==============================] - 7s 81ms/step - loss: 0.7870 - accuracy: 0.7114 - val_loss: 0.7668 - val_accuracy: 0.7132
# Epoch 5/10
# 88/88 [==============================] - 7s 82ms/step - loss: 0.7285 - accuracy: 0.7327 - val_loss: 0.7360 - val_accuracy: 0.7307
# Epoch 6/10
# 88/88 [==============================] - 7s 78ms/step - loss: 0.6861 - accuracy: 0.7500 - val_loss: 0.7012 - val_accuracy: 0.7431
# Epoch 7/10
# 88/88 [==============================] - 7s 83ms/step - loss: 0.6073 - accuracy: 0.7845 - val_loss: 0.7060 - val_accuracy: 0.7474
# Epoch 8/10
# 88/88 [==============================] - 7s 76ms/step - loss: 0.5955 - accuracy: 0.7855 - val_loss: 0.6730 - val_accuracy: 0.7577
# Epoch 9/10
# 88/88 [==============================] - 7s 80ms/step - loss: 0.5691 - accuracy: 0.8032 - val_loss: 0.6730 - val_accuracy: 0.7588
# Epoch 10/10
# 88/88 [==============================] - 7s 75ms/step - loss: 0.5486 - accuracy: 0.7971 - val_loss: 0.6689 - val_accuracy: 0.7606

# %%
def plot_accuracy_loss(history):
    """
        Plot the accuracy and the loss during the training of the nn.
    """
    fig = plt.figure(figsize=(15,10))

    # Plot accuracy
    plt.subplot(221)
    plt.plot(history.history['accuracy'],'bo--', label = "acc")
    plt.plot(history.history['val_accuracy'], 'ro--', label = "val_acc")
    plt.title("train_acc vs val_acc")
    plt.ylabel("accuracy")
    plt.xlabel("epochs")
    plt.legend()

    # Plot loss function
    plt.subplot(222)
    plt.plot(history.history['loss'],'bo--', label = "loss")
    plt.plot(history.history['val_loss'], 'ro--', label = "val_loss")
    plt.title("train_loss vs val_loss")
    plt.ylabel("loss")
    plt.xlabel("epochs")

    plt.legend()
    plt.show()

# %%
plot_accuracy_loss(history)

# %% [markdown]
# We should evaluate the model performance on test set

# %%
test_loss = model.evaluate(test_images, test_labels)
# Out:
# 94/94 [==============================] - 0s 4ms/step - loss: 0.6823 - accuracy: 0.7520

# %%
test_loss
# Out:
# [0.6823080778121948, 0.7519999742507935]

# %% [markdown]
# We see that we achieve 0.76 accuracy on the testing test. We got a slight underfitting :(
#
# Let's see how the classifier is doing on random images.

# %%
predictions = model.predict(test_images)     # Vector of probabilities
pred_labels = np.argmax(predictions, axis = 1) # We take the highest probability

display_random_image(class_names, test_images, pred_labels)

# %% [markdown]
# ## Error analysis
#
# We can try to understand on which kind of images the classifier has trouble.

# %%
def print_mislabeled_images(class_names, test_images, test_labels, pred_labels):
    """
        Print 25 examples of mislabeled images by the classifier, e.g when test_labels != pred_labels
    """
    BOO = (test_labels == pred_labels)
    mislabeled_indices = np.where(BOO == 0)
    mislabeled_images = test_images[mislabeled_indices]
    mislabeled_labels = pred_labels[mislabeled_indices]

    title = "Some examples of mislabeled images by the classifier:"
    display_examples(class_names,  mislabeled_images, mislabeled_labels)

# %%
print_mislabeled_images(class_names, test_images, test_labels, pred_labels)

# %%
CM = confusion_matrix(test_labels, pred_labels)
ax = plt.axes()
sn.heatmap(CM, annot=True, 
           annot_kws={"size": 10}, 
           xticklabels=class_names, 
           yticklabels=class_names, ax = ax)
ax.set_title('Confusion matrix')
plt.show()

# %% [markdown]
# ## Conclusion: The classifier has trouble with 2 kinds of images.
# It has trouble with street and buildings. Well, it can be understandable as as there are buildings in the street.
# It has also trouble with sea, glacier and moutain as well. It is hard for me to fully distinguish them.
# However, it can detects forest very accurately!

# %% [markdown]
# **Intermediate Update January 2020**
#
# * Feature extraction with VGG16 trained on ImageNet
#
#
# * Ensemble models of Neural Networks with the features extracted from VGG
#
# Inspired from: https://machinelearningmastery.com/model-averaging-ensemble-for-deep-learning-neural-networks/
#
# * Fine Tuning with VGG16 trained on ImageNet

# %% [markdown]
# # Feature extraction with VGG ImageNet

# %% [markdown]
# We can extract features from VGG16.

# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input

model = VGG16(weights='imagenet', include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 5s 0us/step

# %% [markdown]
# Get the features directly from VGG16

# %%
train_features = model.predict(train_images)
test_features = model.predict(test_images)

# %% [markdown]
# ## Visualize the features through PCA

# %%
n_train, x, y, z = train_features.shape
n_test, x, y, z = test_features.shape
numFeatures = x * y * z

# %%
numFeatures
# Out:
# 512

# %%
from sklearn import decomposition

pca = decomposition.PCA(n_components = 2)

X = train_features.reshape((n_train, x*y*z))
pca.fit(X)

C = pca.transform(X) # Représentation des individus dans les nouveaux axe
C1 = C[:,0]
C2 = C[:,1]

# %%
### Figures

plt.subplots(figsize=(10,10))

for i, class_name in enumerate(class_names):
    plt.scatter(C1[train_labels == i][:1000], C2[train_labels == i][:1000], label = class_name, alpha=0.4)
plt.legend()
plt.title("PCA Projection")
plt.show()

# %% [markdown]
# We can identifying clusters thanks to this PCA. The clusters correspond more or less to the labels.
#
# We see that glacier and mountain points are very close to each other, as VGG sees them as very similar.
#
# We see that there is no distinction between building and street.

# %% [markdown]
# ## Training on top of VGG
#
# Let's train a simple one-layer Neural Network on the features extracted from VGG.

# %%
model2 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape = (x, y, z)),
    tf.keras.layers.Dense(50, activation=tf.nn.relu),
    tf.keras.layers.Dense(6, activation=tf.nn.softmax)
])

model2.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

history2 = model2.fit(train_features, train_labels, batch_size=128, epochs=15, validation_split = 0.2)
# Out:
# Epoch 1/15
# 88/88 [==============================] - 0s 3ms/step - loss: 1.4289 - accuracy: 0.4666 - val_loss: 0.8625 - val_accuracy: 0.6865
# Epoch 2/15
# 88/88 [==============================] - 0s 1ms/step - loss: 0.8226 - accuracy: 0.7061 - val_loss: 0.7681 - val_accuracy: 0.7157
# Epoch 3/15
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7362 - accuracy: 0.7327 - val_loss: 0.7317 - val_accuracy: 0.7300
# Epoch 4/15
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6959 - accuracy: 0.7494 - val_loss: 0.7106 - val_accuracy: 0.7399
# Epoch 5/15
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6795 - accuracy: 0.7552 - val_loss: 0.6989 - val_accuracy: 0.7481
# Epoch 6/15
# 88/88 [==============================] - 0s 1ms/step - loss: 0.6655 - accuracy: 0.7590 - val_loss: 0.6836 - val_accuracy: 0.7506
# Epoch 7/15
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6408 - accuracy: 0.7720 - val_loss: 0.6846 - val_accuracy: 0.7467
# Epoch 8/15
# 88/88 [==============================] - 0s 3ms/step - loss: 0.6284 - accuracy: 0.7729 - val_loss: 0.6747 - val_accuracy: 0.7528
# Epoch 9/15
# 88/88 [==============================] - 0s 1ms/step - loss: 0.6202 - accuracy: 0.7747 - val_loss: 0.6687 - val_accuracy: 0.7520
# Epoch 10/15
# 88/88 [==============================] - 0s 2ms/step - loss: 0.5972 - accuracy: 0.7836 - val_loss: 0.6658 - val_accuracy: 0.7549
# Epoch 11/15
# 88/88 [==============================] - 0s 1ms/step - loss: 0.5938 - accuracy: 0.7838 - val_loss: 0.6696 - val_accuracy: 0.7549
# Epoch 12/15
# 88/88 [==============================] - 0s 1ms/step - loss: 0.5767 - accuracy: 0.7921 - val_loss: 0.6706 - val_accuracy: 0.7488
# Epoch 13/15
# 88/88 [==============================] - 0s 2ms/step - loss: 0.5765 - accuracy: 0.7894 - val_loss: 0.6593 - val_accuracy: 0.7588
# Epoch 14/15
# 88/88 [==============================] - 0s 1ms/step - loss: 0.5639 - accuracy: 0.7947 - val_loss: 0.6635 - val_accuracy: 0.7563
# Epoch 15/15
# 88/88 [==============================] - 0s 1ms/step - loss: 0.5694 - accuracy: 0.7948 - val_loss: 0.6619 - val_accuracy: 0.7602

# %%
plot_accuracy_loss(history)

# %% [markdown]
# We should get approximately 0.844 accuracy (+0.1 accuracy) over the simple ConvNet.

# %%
test_loss = model2.evaluate(test_features, test_labels)
# Out:
# 94/94 [==============================] - 0s 729us/step - loss: 0.6709 - accuracy: 0.7480

# %% [markdown]
# # Ensemble Neural Networks

# %%
np.random.seed(seed=1997)
# Number of estimators
n_estimators = 10
# Proporition of samples to use to train each training
max_samples = 0.8

max_samples *= n_train
max_samples = int(max_samples)

# %% [markdown]
# We define n_estimators Neural Networks.
#
# Each Neural Network will be trained on random subsets of the training dataset. Each subset contains max_samples samples.

# %%
models = list()
random = np.random.randint(50, 100, size = n_estimators)

for i in range(n_estimators):
    
    # Model
    model = tf.keras.Sequential([ tf.keras.layers.Flatten(input_shape = (x, y, z)),
                                # One layer with random size
                                    tf.keras.layers.Dense(random[i], activation=tf.nn.relu),
                                    tf.keras.layers.Dense(6, activation=tf.nn.softmax)
                                ])
    
    model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])
    
    # Store model
    models.append(model)

# %%
histories = []

for i in range(n_estimators):
    # Train each model on a bag of the training data
    train_idx = np.random.choice(len(train_features), size = max_samples)
    histories.append(models[i].fit(train_features[train_idx], train_labels[train_idx], batch_size=128, epochs=10, validation_split = 0.1))
# Out:
# Epoch 1/10
# 79/79 [==============================] - 0s 3ms/step - loss: 1.3666 - accuracy: 0.4767 - val_loss: 0.8447 - val_accuracy: 0.7061
# Epoch 2/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.8050 - accuracy: 0.7070 - val_loss: 0.7416 - val_accuracy: 0.7480
# Epoch 3/10
# 79/79 [==============================] - ETA: 0s - loss: 0.6924 - accuracy: 0.75 - 0s 1ms/step - loss: 0.6977 - accuracy: 0.7519 - val_loss: 0.7098 - val_accuracy: 0.7551
# Epoch 4/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6830 - accuracy: 0.7451 - val_loss: 0.6747 - val_accuracy: 0.7614
# Epoch 5/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.6301 - accuracy: 0.7751 - val_loss: 0.6590 - val_accuracy: 0.7605
# Epoch 6/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6071 - accuracy: 0.7746 - val_loss: 0.6494 - val_accuracy: 0.7792
# Epoch 7/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.5878 - accuracy: 0.7834 - val_loss: 0.6633 - val_accuracy: 0.7524
# Epoch 8/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.5716 - accuracy: 0.7946 - val_loss: 0.6305 - val_accuracy: 0.7792
# Epoch 9/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.5590 - accuracy: 0.8015 - val_loss: 0.6299 - val_accuracy: 0.7872
# Epoch 10/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.5434 - accuracy: 0.8061 - val_loss: 0.6285 - val_accuracy: 0.7792
# Epoch 1/10
# 79/79 [==============================] - 0s 4ms/step - loss: 1.4078 - accuracy: 0.4730 - val_loss: 0.7989 - val_accuracy: 0.7088
# Epoch 2/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.7740 - accuracy: 0.7265 - val_loss: 0.6980 - val_accuracy: 0.7471
# Epoch 3/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.7037 - accuracy: 0.7483 - val_loss: 0.6714 - val_accuracy: 0.7524
# Epoch 4/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6550 - accuracy: 0.7586 - val_loss: 0.6339 - val_accuracy: 0.7649
# Epoch 5/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6241 - accuracy: 0.7739 - val_loss: 0.6121 - val_accuracy: 0.7694
# Epoch 6/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6003 - accuracy: 0.7813 - val_loss: 0.6066 - val_accuracy: 0.7711
# Epoch 7/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5797 - accuracy: 0.7888 - val_loss: 0.6030 - val_accuracy: 0.7720
# Epoch 8/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5647 - accuracy: 0.7940 - val_loss: 0.5845 - val_accuracy: 0.7845
# Epoch 9/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5486 - accuracy: 0.8014 - val_loss: 0.5677 - val_accuracy: 0.7836
# Epoch 10/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5364 - accuracy: 0.8042 - val_loss: 0.5650 - val_accuracy: 0.7907
# Epoch 1/10
# 79/79 [==============================] - 0s 3ms/step - loss: 1.4689 - accuracy: 0.4465 - val_loss: 0.9107 - val_accuracy: 0.6634
# Epoch 2/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.8233 - accuracy: 0.7013 - val_loss: 0.7974 - val_accuracy: 0.7133
# Epoch 3/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6999 - accuracy: 0.7537 - val_loss: 0.7724 - val_accuracy: 0.7106
# Epoch 4/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6849 - accuracy: 0.7525 - val_loss: 0.7481 - val_accuracy: 0.7293
# Epoch 5/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6306 - accuracy: 0.7748 - val_loss: 0.7360 - val_accuracy: 0.7257
# Epoch 6/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6253 - accuracy: 0.7756 - val_loss: 0.7219 - val_accuracy: 0.7222
# Epoch 7/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6027 - accuracy: 0.7835 - val_loss: 0.7048 - val_accuracy: 0.7275
# Epoch 8/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.5918 - accuracy: 0.7836 - val_loss: 0.6937 - val_accuracy: 0.7462
# Epoch 9/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5703 - accuracy: 0.7938 - val_loss: 0.6910 - val_accuracy: 0.7418
# Epoch 10/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5378 - accuracy: 0.8042 - val_loss: 0.6935 - val_accuracy: 0.7427
# Epoch 1/10
# 79/79 [==============================] - 1s 4ms/step - loss: 1.4027 - accuracy: 0.4638 - val_loss: 0.8841 - val_accuracy: 0.6803
# Epoch 2/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.8312 - accuracy: 0.6992 - val_loss: 0.7759 - val_accuracy: 0.7142
# Epoch 3/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.7152 - accuracy: 0.7376 - val_loss: 0.7235 - val_accuracy: 0.7266
# Epoch 4/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.6655 - accuracy: 0.7691 - val_loss: 0.6992 - val_accuracy: 0.7516
# Epoch 5/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6527 - accuracy: 0.7633 - val_loss: 0.6904 - val_accuracy: 0.7435
# Epoch 6/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.6401 - accuracy: 0.7676 - val_loss: 0.6733 - val_accuracy: 0.7533
# Epoch 7/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.5912 - accuracy: 0.7874 - val_loss: 0.6729 - val_accuracy: 0.7658
# Epoch 8/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5742 - accuracy: 0.7898 - val_loss: 0.6483 - val_accuracy: 0.7614
# Epoch 9/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5693 - accuracy: 0.7977 - val_loss: 0.6529 - val_accuracy: 0.7720
# Epoch 10/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5550 - accuracy: 0.7997 - val_loss: 0.6342 - val_accuracy: 0.7649
# Epoch 1/10
# 79/79 [==============================] - 0s 3ms/step - loss: 1.3934 - accuracy: 0.4747 - val_loss: 0.8763 - val_accuracy: 0.6750
# Epoch 2/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.7979 - accuracy: 0.7197 - val_loss: 0.7944 - val_accuracy: 0.7026
# Epoch 3/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.7109 - accuracy: 0.7409 - val_loss: 0.7545 - val_accuracy: 0.7231
# Epoch 4/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6788 - accuracy: 0.7592 - val_loss: 0.7155 - val_accuracy: 0.7382
# Epoch 5/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6465 - accuracy: 0.7645 - val_loss: 0.7007 - val_accuracy: 0.7409
# Epoch 6/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.5951 - accuracy: 0.7861 - val_loss: 0.6939 - val_accuracy: 0.7507
# Epoch 7/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5914 - accuracy: 0.7876 - val_loss: 0.6865 - val_accuracy: 0.7551
# Epoch 8/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.5842 - accuracy: 0.7915 - val_loss: 0.6668 - val_accuracy: 0.7587
# Epoch 9/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5647 - accuracy: 0.7932 - val_loss: 0.6664 - val_accuracy: 0.7427
# Epoch 10/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.5589 - accuracy: 0.7997 - val_loss: 0.6461 - val_accuracy: 0.7658
# Epoch 1/10
# 79/79 [==============================] - 1s 4ms/step - loss: 1.4557 - accuracy: 0.4553 - val_loss: 0.8420 - val_accuracy: 0.7008
# Epoch 2/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.8086 - accuracy: 0.7065 - val_loss: 0.7471 - val_accuracy: 0.7489
# Epoch 3/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6994 - accuracy: 0.7410 - val_loss: 0.7127 - val_accuracy: 0.7435
# Epoch 4/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6550 - accuracy: 0.7635 - val_loss: 0.6765 - val_accuracy: 0.7542
# Epoch 5/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6290 - accuracy: 0.7653 - val_loss: 0.6661 - val_accuracy: 0.7658
# Epoch 6/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6110 - accuracy: 0.7710 - val_loss: 0.6404 - val_accuracy: 0.7720
# Epoch 7/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5631 - accuracy: 0.7913 - val_loss: 0.6354 - val_accuracy: 0.7747
# Epoch 8/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5580 - accuracy: 0.7924 - val_loss: 0.6275 - val_accuracy: 0.7801
# Epoch 9/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5172 - accuracy: 0.8109 - val_loss: 0.6388 - val_accuracy: 0.7720
# Epoch 10/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.5215 - accuracy: 0.8106 - val_loss: 0.6260 - val_accuracy: 0.7774
# Epoch 1/10
# 79/79 [==============================] - 0s 3ms/step - loss: 1.4111 - accuracy: 0.4642 - val_loss: 0.8572 - val_accuracy: 0.6732
# Epoch 2/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.8147 - accuracy: 0.6936 - val_loss: 0.7745 - val_accuracy: 0.7186
# Epoch 3/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.7443 - accuracy: 0.7278 - val_loss: 0.7201 - val_accuracy: 0.7346
# Epoch 4/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.6852 - accuracy: 0.7461 - val_loss: 0.7258 - val_accuracy: 0.7168
# Epoch 5/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6513 - accuracy: 0.7566 - val_loss: 0.6981 - val_accuracy: 0.7391
# Epoch 6/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6104 - accuracy: 0.7809 - val_loss: 0.6747 - val_accuracy: 0.7569
# Epoch 7/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6155 - accuracy: 0.7757 - val_loss: 0.6651 - val_accuracy: 0.7569
# Epoch 8/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5786 - accuracy: 0.7921 - val_loss: 0.6561 - val_accuracy: 0.7596
# Epoch 9/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5704 - accuracy: 0.8017 - val_loss: 0.6402 - val_accuracy: 0.7738
# Epoch 10/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.5514 - accuracy: 0.8020 - val_loss: 0.6401 - val_accuracy: 0.7818
# Epoch 1/10
# 79/79 [==============================] - 0s 4ms/step - loss: 1.3974 - accuracy: 0.4799 - val_loss: 0.8347 - val_accuracy: 0.7115
# Epoch 2/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.7958 - accuracy: 0.7117 - val_loss: 0.7530 - val_accuracy: 0.7444
# Epoch 3/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.7186 - accuracy: 0.7338 - val_loss: 0.7196 - val_accuracy: 0.7418
# Epoch 4/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.6810 - accuracy: 0.7512 - val_loss: 0.6953 - val_accuracy: 0.7587
# Epoch 5/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6518 - accuracy: 0.7619 - val_loss: 0.6708 - val_accuracy: 0.7605
# Epoch 6/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6335 - accuracy: 0.7717 - val_loss: 0.6528 - val_accuracy: 0.7756
# Epoch 7/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.6069 - accuracy: 0.7797 - val_loss: 0.6469 - val_accuracy: 0.7685
# Epoch 8/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5777 - accuracy: 0.7893 - val_loss: 0.6392 - val_accuracy: 0.7756
# Epoch 9/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5802 - accuracy: 0.7890 - val_loss: 0.6360 - val_accuracy: 0.7792
# Epoch 10/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5467 - accuracy: 0.8003 - val_loss: 0.6213 - val_accuracy: 0.7792
# Epoch 1/10
# 79/79 [==============================] - 0s 3ms/step - loss: 1.4086 - accuracy: 0.4839 - val_loss: 0.8863 - val_accuracy: 0.6866
# Epoch 2/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.8047 - accuracy: 0.7094 - val_loss: 0.7665 - val_accuracy: 0.7195
# Epoch 3/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.7180 - accuracy: 0.7379 - val_loss: 0.7286 - val_accuracy: 0.7177
# Epoch 4/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.6831 - accuracy: 0.7418 - val_loss: 0.7064 - val_accuracy: 0.7222
# Epoch 5/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6538 - accuracy: 0.7624 - val_loss: 0.6766 - val_accuracy: 0.7462
# Epoch 6/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.6325 - accuracy: 0.7740 - val_loss: 0.6598 - val_accuracy: 0.7551
# Epoch 7/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.6019 - accuracy: 0.7839 - val_loss: 0.6363 - val_accuracy: 0.7498
# Epoch 8/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.5710 - accuracy: 0.7977 - val_loss: 0.6282 - val_accuracy: 0.7542
# Epoch 9/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5577 - accuracy: 0.8031 - val_loss: 0.6185 - val_accuracy: 0.7685
# Epoch 10/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5544 - accuracy: 0.8016 - val_loss: 0.6184 - val_accuracy: 0.7622
# Epoch 1/10
# 79/79 [==============================] - 0s 3ms/step - loss: 1.4335 - accuracy: 0.4688 - val_loss: 0.8471 - val_accuracy: 0.7044
# Epoch 2/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.8146 - accuracy: 0.7068 - val_loss: 0.7418 - val_accuracy: 0.7382
# Epoch 3/10
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7247 - accuracy: 0.7407 - val_loss: 0.7033 - val_accuracy: 0.7507
# Epoch 4/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6827 - accuracy: 0.7590 - val_loss: 0.6805 - val_accuracy: 0.7622
# Epoch 5/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6482 - accuracy: 0.7668 - val_loss: 0.6625 - val_accuracy: 0.7622
# Epoch 6/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.6350 - accuracy: 0.7704 - val_loss: 0.6683 - val_accuracy: 0.7640
# Epoch 7/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.6177 - accuracy: 0.7724 - val_loss: 0.6397 - val_accuracy: 0.7765
# Epoch 8/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5898 - accuracy: 0.7861 - val_loss: 0.6382 - val_accuracy: 0.7756
# Epoch 9/10
# 79/79 [==============================] - 0s 1ms/step - loss: 0.5659 - accuracy: 0.7942 - val_loss: 0.6363 - val_accuracy: 0.7720
# Epoch 10/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5624 - accuracy: 0.7944 - val_loss: 0.6217 - val_accuracy: 0.7774

# %% [markdown]
# We aggregate each model individual predictions to form a final prediction.

# %%
predictions = []
for i in range(n_estimators):
    predictions.append(models[i].predict(test_features))
    
predictions = np.array(predictions)
predictions = predictions.sum(axis = 0)
pred_labels = predictions.argmax(axis=1)

# %% [markdown]
# We should improve our result as we have a lower variance.

# %%
from sklearn.metrics import accuracy_score
print("Accuracy : {}".format(accuracy_score(test_labels, pred_labels)))
# Out:
# Accuracy : 0.7483333333333333
