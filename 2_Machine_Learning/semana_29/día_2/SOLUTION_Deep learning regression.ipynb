# %% [markdown]
# # Regresion Basica: Predecir eficiencia de gasolina

# %% [markdown]
# Este libro usa el set de datos clasico [Auto MPG](https://archive.ics.uci.edu/ml/datasets/auto+mpg) y construye un modelo para predecir el consumo de vehiculos de 1970 y 1980. Para hacer esto proveeremos el modelo con una descripcion de muchos automoviles de ese periodo. Esta descripcion incluye atributos como: Cilindros, desplazamiento, potencia y peso.
#
# El objetivo de este ejercicio es predecir el target miles per galon (MPG), que vendría a representar las millas por galón de combustible.
#
# Este ejemplo usa el API `tf.keras` , revise [Esta Guia](https://www.tensorflow.org/guide/keras) para obtener mas detalles.

# %%
import pathlib

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.4.1

# %% [markdown]
# ## El set de Datos de MPG
#
# El set de datos esta disponible de el siguiente repositorio [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/).

# %% [markdown]
# ### Obtenga los datos
# Primero descargue el set de datos.

# %%
dataset_path = keras.utils.get_file("auto-mpg.data",
                                    "http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data")
dataset_path
# Out:
# 'C:\\Users\\pilar\\.keras\\datasets\\auto-mpg.data'

# %% [markdown]
# Importelo usando pandas.

# %%
column_names = ['MPG','Cylinders','Displacement','Horsepower','Weight',
                'Acceleration', 'Model Year', 'Origin']

raw_dataset = pd.read_csv(dataset_path, names=column_names,
                      na_values = "?", comment='\t',
                      sep=" ", skipinitialspace=True)

dataset = raw_dataset.copy()
dataset.tail()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Origin
# 393          82       1
# 394          82       2
# 395          82       1
# 396          82       1
# 397          82       1

# %% [markdown]
# ### Limpia los datos
#
# Trata los missings y variables categóricas

# %%
dataset.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      6
# Weight          0
# Acceleration    0
# Model Year      0
# Origin          0
# dtype: int64

# %%
dataset = dataset.dropna()

# %%
# la columna de 'Origin' realmente es categórica, no numérica. La convierto en un one-hot
origin = dataset.pop('Origin')

# %%
dataset['USA'] = (origin == 1)*1.0
dataset['Europe'] = (origin == 2)*1.0
dataset['Japan'] = (origin == 3)*1.0
dataset.tail()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  USA  Europe  Japan
# 393          82  1.0     0.0    0.0
# 394          82  0.0     1.0    0.0
# 395          82  1.0     0.0    0.0
# 396          82  1.0     0.0    0.0
# 397          82  1.0     0.0    0.0

# %% [markdown]
# ### Divide los datos en train y test
#
# Ahora divida el set de datos en un set de entrenamiento y otro de pruebas. 80% para entrenamiento
#
# Usaremos el set de pruebas en la evaluacion final de nuestro modelo.
#
# NOTA: El resultado tienen que ser dos datasets

# %%
train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)

# %% [markdown]
# ### Inspecciona los datos
#
# Revise rapidamente la distribucion conjunta del dataset de entrenamiento mediante un grid de gráficos

# %%
sns.pairplot(train_dataset[["MPG", "Cylinders", "Displacement", "Weight"]], diag_kind = "kde");

# %% [markdown]
# Tambien revise las estadisticas generales:

# %%
train_stats = train_dataset.describe()
train_stats.pop("MPG")
train_stats = train_stats.transpose()
train_stats
# Out:
#               count         mean         std     min      25%     50%  \
# Cylinders     314.0     5.477707    1.699788     3.0     4.00     4.0
# Displacement  314.0   195.318471  104.331589    68.0   105.50   151.0
# Horsepower    314.0   104.869427   38.096214    46.0    76.25    94.5
# Weight        314.0  2990.251592  843.898596  1649.0  2256.50  2822.5
# Acceleration  314.0    15.559236    2.789230     8.0    13.80    15.5
# Model Year    314.0    75.898089    3.675642    70.0    73.00    76.0
# USA           314.0     0.624204    0.485101     0.0     0.00     1.0
# Europe        314.0     0.178344    0.383413     0.0     0.00     0.0
# Japan         314.0     0.197452    0.398712     0.0     0.00     0.0
#
#                   75%     max
# Cylinders        8.00     8.0
# Displacement   265.75   455.0
# Horsepower     128.00   225.0
# Weight        3608.00  5140.0
# Acceleration    17.20    24.8
# Model Year      79.00    82.0
# USA              1.00     1.0
# Europe           0.00     1.0
# Japan            0.00     1.0

# %% [markdown]
# ### Separa las features del target
#
# Separe el target de las features.

# %%
train_labels = train_dataset.pop("MPG")
test_labels = test_dataset.pop("MPG")

# %% [markdown]
# ### Estandariza los datos

# %% [markdown]
# Es una buena práctica estandarizar funciones que utilizan diferentes escalas y rangos. Aunque el modelo podría converger sin estandarizar, dificulta el entrenamiento y hace que el modelo resultante dependa de la elección de las unidades utilizadas en la entrada.

# %%
def norm(x):
    return (x- train_stats['mean'])/ train_stats['std']

normed_trained_data = norm(train_dataset)
normed_test_data = norm(test_dataset)

# %% [markdown]
# Estos datos estandarizados es lo que usaremos para entrenar el modelo.

# %% [markdown]
# ## El modelo

# %% [markdown]
# ### Construye el modelo
#
# Construyamos nuestro modelo. Aquí, utilizaremos un modelo `secuencial` con dos capas ocultas densamente conectadas y una capa de salida que devuelve un único valor continuo.
#
# Por tanto, tendrá tres capas. Una de entrada con activación relu. Otra hidden layer con activación relu y la de salida de regresión, que se compondrá de una única neurona. Pon las neuronas que consideres para las dos primeras capas.
#
# Para el compile utiliza un loss='mse'.
#
# optimizer = `tf.keras.optimizers.RMSprop(0.001)`
#
# Y en metrics añade en una lista el `mae` y `mse`.

# %%
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape = [len(train_dataset.keys())]),
    layers.Dense(64, activation = 'relu'),
    layers.Dense(1)   
])

model.compile(loss='mse', 
             optimizer=tf.keras.optimizers.RMSprop(0.001),
             metrics = ['mae', 'mse'])

# %% [markdown]
# ### Inspeccione el modelo
#
# Use el método `.summary` para imprimir una descripción simple del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                640
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 4,865
# Trainable params: 4,865
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Entrenar el modelo
#
# Entrene el modelo para 1000 epochs y guarda los resultados del entrenamiento en una variable llamada `history`.
# Emplea en el entrenamiento un 20% de los datos para validación, mediante el argumento `validation_split`.
#
# NOTA: recuerda usar los datos normalizados.

# %%
history = model.fit(
normed_trained_data, train_labels,
epochs = 1000, validation_split = 0.2, verbose=0)

# %% [markdown]
# Visualice el progreso de entrenamiento del modelo usando las estadísticas almacenadas en el objeto `history`.

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#          loss       mae       mse  val_loss   val_mae   val_mse  epoch
# 995  2.797926  1.012317  2.797926  9.599940  2.385301  9.599940    995
# 996  2.669427  1.014385  2.669427  9.682835  2.369748  9.682835    996
# 997  2.530392  0.963393  2.530392  9.270757  2.316807  9.270757    997
# 998  2.674942  0.996628  2.674942  9.316434  2.280483  9.316434    998
# 999  2.598693  0.991315  2.598693  9.566707  2.375769  9.566707    999

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error [MPG]')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.ylim([0,5])
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error [$MPG^2$]')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  plt.ylim([0,20])
  plt.legend()
  plt.show()


plot_history(history)

# %% [markdown]
# ¿Alguna conclusión respecto a este gráfico?

# %%
'''
Este gráfico muestra poca mejora,
incluso degradación en el error de validación después de aprox. 100 épocas.
Actualizamos la llamada del model.fit para detener automáticamente el entrenamiento
cuando la puntuación de validación no mejore.
Utilizamos una devolución de llamada de EarlyStopping que pruebe una condición de entrenamiento
en cada época.
Si transcurre una cantidad determinada de épocas sin mostrar mejorías, entonces
detiene automáticamente el entrenamiento.

'''
# Out:
# '\nEste gráfico muestra poca mejora,\nincluso degradación en el error de validación después de aprox. 100 épocas.\nActualizamos la llamada del model.fit para detener automáticamente el entrenamiento\ncuando la puntuación de validación no mejore.\nUtilizamos una devolución de llamada de EarlyStopping que pruebe una condición de entrenamiento\nen cada época.\nSi transcurre una cantidad determinada de épocas sin mostrar mejorías, entonces\ndetiene automáticamente el entrenamiento.\n\n'

# %% [markdown]
# Añade un early stopping al modelo. Pon el argumento `callbacks=[keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)]` dentro del fit().
#
# Después del entrenamiento utiliza la función del apartado anterior `plot_history(history)`.

# %%
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape = [len(train_dataset.keys())]),
    layers.Dense(64, activation = 'relu'),
    layers.Dense(1)   
])

model.compile(loss='mse', 
             optimizer=tf.keras.optimizers.RMSprop(0.001),
             metrics = ['mae', 'mse'])

history = model.fit( normed_trained_data,
                   train_labels, epochs=1000,
                   validation_split = 0.2,
                   verbose=0,
                   callbacks = [keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)])

plot_history(history)

# %% [markdown]
# Interpreta el gráfico

# %%
'''
se muestra que en el conjunto de validación el error promedio es aprox. de +/- 2 MPG.
¿Es esto bueno? Le dejamos a usted la conclusión

'''
# Out:
# '\nse muestra que en el conjunto de validación el error promedio es aprox. de +/- 2 MPG.\n¿Es esto bueno? Le dejamos a usted la conclusión\n\n'

# %% [markdown]
# Veamos qué tan bien generaliza el modelo al usar el conjunto de **test**. Esto nos dice qué tan bien podemos esperar que el modelo prediga cuándo lo usamos en el mundo real. Utiliza el método `evaluate` con los datos de test normalizados y sus labels.
#
# Con el método evaluate devolverá tres valores: loss, mae y mse.

# %%
loss, mae, mse = model.evaluate(normed_test_data, test_labels, verbose=2)
print("Testing set MAE: {:5.2f} MPG". format(mae))
# Out:
# 3/3 - 0s - loss: 5.6224 - mae: 1.7941 - mse: 5.6224
# Testing set MAE:  1.79 MPG

# %% [markdown]
# Ahora prueba el modelo. Coge 10 ejemplos de train y llama a` model.predict`.

# %%
example_batch = normed_trained_data[:10]
example_result = model.predict(example_batch)
example_result
# Out:
# array([[28.078342],
#        [23.580692],
#        [12.955967],
#        [36.24398 ],
#        [34.251358],
#        [19.983368],
#        [36.27077 ],
#        [29.33165 ],
#        [18.425621],
#        [24.821215]], dtype=float32)

# %%
train_labels[:10]
# Out:
# 146    28.0
# 282    22.3
# 69     12.0
# 378    38.0
# 331    33.8
# 257    19.4
# 310    38.1
# 328    30.0
# 125    20.0
# 108    20.0
# Name: MPG, dtype: float64

# %% [markdown]
# ### Haz Predicciones
#
# Dibuja en un scatter plot las predicciones de test vs sus true labels.

# %%
test_predictions = model.predict(normed_test_data).flatten()

plt.scatter(test_labels, test_predictions)
plt.xlabel("True values [MPG]")
plt.ylabel("Predictions [MPG]")
plt.axis('equal')
plt.axis("square")
plt.xlim([0, plt.xlim()[1]])
plt.ylim([0, plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])

# %% [markdown]
# Parece que nuestro modelo predice razonablemente bien. Echemos un vistazo a la distribución de errores.
#
# Representa los residuos en un histograma

# %%
error = test_predictions - test_labels
plt.hist(error, bins=25)
plt.xlabel("Prediction error [MPG]")
_ = plt.ylabel("Count")

# %% [markdown]
# No es del todo gaussiano, pero podríamos esperar eso porque el número de muestras es muy pequeño.

# %% [markdown]
# ## Conclusion
#
# Este cuaderno introdujo algunas técnicas para manejar un problema de regresión.
#
# * El error cuadrático medio (MSE) es una función de pérdida común utilizada para problemas de regresión (se utilizan diferentes funciones de pérdida para problemas de clasificación).
# * Del mismo modo, las métricas de evaluación utilizadas para la regresión difieren de la clasificación. Una métrica de regresión común es el error absoluto medio (MAE).
# * Cuando las características de datos de entrada numéricos tienen valores con diferentes rangos, cada característica debe escalarse independientemente al mismo rango.
# * Si no hay muchos datos de entrenamiento, una técnica es preferir una red pequeña con pocas capas ocultas para evitar el sobreajuste.
# * La detención temprana es una técnica útil para evitar el sobreajuste.
