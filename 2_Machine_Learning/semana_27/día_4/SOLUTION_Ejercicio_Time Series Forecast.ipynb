# %% [markdown]
# ## Ejercicio Time Series Forecast
# Para este ejercicio vamos a predecir cuál será la demanda de pasajeros de una aerolinea, para poder anticiparse a las contrataciones de personal, mantenimiento de las aeronaves y gestión de inventario y comidas.
#
# Para ello, se pide:
# 1. Carga datos (AirPassengers.csv) y representa la serie. ¿Hay seasonality? ¿Cada cuanto?
# 2. Crea en una gráfica la variable original + su media obtenida mediante una rolling window con el valor de seasonality obtenido en el apartado anterior. Tienes que usar la función rolling() del DataFrame.
# 3. Comprueba de manera estadística si la serie es o no stationary.
# 4. Aplica una transformación logarítmica sobre los datos para mejorar el proceso de transformación de tu time series a stationary. Acuérdate después del forecast de invertir la transformación.
# 5. Divide en train y test. Guarda 20 muestras para test.
# 6. Crea tu primer modelo ARIMA. Habrá varias combinaciones en función de sus hiperparámetros... Mide el MAE y RMSE del modelo en predicción. Ten en cuenta el parámetro "m" de la función ARIMA, mediante el cual se establece el seasonality.
# 7. Representa en una gráfica los datos de test y tus predicciones.
# 8. Prueba un decission tree y un random forest, a ver qué performance presentan.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 1. Carga datos y representa la serie

# %%
df = pd.read_csv('data/AirPassengers.csv')

df['date'] = pd.to_datetime(df['date'],
                           infer_datetime_format=True)

df.set_index('date', inplace=True)
df.head()
# Out:
#             value
# date
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121

# %%
df.plot();
df[:24*2].plot();

# %% [markdown]
# ## 2. Crea en una gráfica la variable original + su media obtenida mediante una rolling window con el valor de seasonality obtenido en el apartado anterior

# %%
rolmean = df.rolling(window=12).mean()
rolstd = df.rolling(window=12).std()

orig = plt.plot(df, color='blue', label='Original')
mean = plt.plot(rolmean, color='red', label='Rolling mean')
std = plt.plot(rolstd, color='black', label='Rolling std')
plt.legend()
plt.title("Rolling mean & Std");

# %% [markdown]
# ## 3. Comprueba de manera estadística si la serie es o no stationary.

# %%
'''
No es statationary por el test de DF, aunque se aprecia claramente en la gráfica.
'''
from statsmodels.tsa.stattools import adfuller

ad_fuller_result = adfuller(df['value'])
print(f'ADF Statistic: {ad_fuller_result[0]}')
print(f'p-value: {ad_fuller_result[1]}')
# Out:
# ADF Statistic: 0.8153688792060433
# p-value: 0.9918802434376409

# %% [markdown]
# ## 4. Aplica una transformación logarítmica

# %%
df['value'] = np.log(df['value'])

# %% [markdown]
# ## 5. Divide en train y test. Guarda 20 muestras para test.

# %%
print(len(df))
train = df['value'][:-20]
test = df['value'][-20:]
print(train.shape)
print(test.shape)
# Out:
# 144
# (124,)
# (20,)

# %% [markdown]
# ## 6. Crea tu primer modelo ARIMA

# %%
from pmdarima.arima import auto_arima, ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# Primero pruebo sin seasonality
model = auto_arima(train,
                  max_p=5,
                  max_q=5,
                  max_d=3,
                  stationary=False,
                  warnings=False,
                  errores_action='ignore',
                  trace=True,
                  stepwise=True)
print(model.aic())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-225.738, Time=0.28 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-201.351, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-202.849, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-204.251, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-202.180, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-229.487, Time=0.18 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-208.997, Time=0.10 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=-204.379, Time=0.05 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=-228.871, Time=0.26 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=-203.109, Time=0.07 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=-229.579, Time=0.29 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=-233.941, Time=0.37 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=-214.822, Time=0.19 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=-232.718, Time=0.40 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=-251.815, Time=0.38 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.51 sec
#  ARIMA(5,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.53 sec
#  ARIMA(4,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.45 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=-237.821, Time=0.41 sec
#  ARIMA(5,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.49 sec
#  ARIMA(4,1,3)(0,0,0)[0]             : AIC=-244.015, Time=0.32 sec
#
# Best model:  ARIMA(4,1,3)(0,0,0)[0] intercept
# Total fit time: 5.590 seconds
# -251.81516690656986

# %%
predictions = model.predict(20)
print('MSE:', mean_squared_error(test.values, predictions))
print('RMSE:', np.sqrt(mean_squared_error(test.values, predictions)))
print('MAE:', mean_absolute_error(test.values, predictions))
# Out:
# MSE: 0.02562603831847829
# RMSE: 0.16008134906502472
# MAE: 0.1401713972444519

# %%
model = auto_arima(train,
                  max_p=5,
                  max_q=5,
                  max_d=3,
                  m=12,
                  stationary=False,
                  warnings=False,
                  errores_action='ignore',
                  trace=True,
                  stepwise=True)
print(model.aic())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=-402.870, Time=1.19 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=-290.649, Time=0.03 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=-399.417, Time=0.79 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=-353.179, Time=0.49 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=-125.472, Time=0.01 sec
#  ARIMA(2,0,2)(0,1,1)[12] intercept   : AIC=-408.701, Time=1.10 sec
#  ARIMA(2,0,2)(0,1,0)[12] intercept   : AIC=-382.319, Time=0.49 sec
#  ARIMA(2,0,2)(0,1,2)[12] intercept   : AIC=-406.713, Time=3.04 sec
#  ARIMA(2,0,2)(1,1,0)[12] intercept   : AIC=-402.096, Time=1.88 sec
#  ARIMA(2,0,2)(1,1,2)[12] intercept   : AIC=-404.632, Time=4.29 sec
#  ARIMA(1,0,2)(0,1,1)[12] intercept   : AIC=-409.957, Time=1.71 sec
#  ARIMA(1,0,2)(0,1,0)[12] intercept   : AIC=-382.629, Time=0.29 sec
#  ARIMA(1,0,2)(1,1,1)[12] intercept   : AIC=-406.922, Time=1.63 sec
#  ARIMA(1,0,2)(0,1,2)[12] intercept   : AIC=-407.996, Time=3.76 sec
#  ARIMA(1,0,2)(1,1,0)[12] intercept   : AIC=-403.422, Time=1.12 sec
#  ARIMA(1,0,2)(1,1,2)[12] intercept   : AIC=-405.536, Time=4.21 sec
#  ARIMA(0,0,2)(0,1,1)[12] intercept   : AIC=-385.348, Time=1.00 sec
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=-411.631, Time=0.79 sec
#  ARIMA(1,0,1)(0,1,0)[12] intercept   : AIC=-384.170, Time=0.21 sec
#  ARIMA(1,0,1)(1,1,1)[12] intercept   : AIC=-409.546, Time=1.28 sec
#  ARIMA(1,0,1)(0,1,2)[12] intercept   : AIC=-409.714, Time=2.59 sec
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=-405.268, Time=1.02 sec
#  ARIMA(1,0,1)(1,1,2)[12] intercept   : AIC=-406.688, Time=2.61 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=-408.087, Time=0.99 sec
#  ARIMA(2,0,1)(0,1,1)[12] intercept   : AIC=-410.683, Time=0.57 sec
#  ARIMA(0,0,0)(0,1,1)[12] intercept   : AIC=-300.825, Time=0.20 sec
#  ARIMA(2,0,0)(0,1,1)[12] intercept   : AIC=-412.379, Time=0.82 sec
#  ARIMA(2,0,0)(0,1,0)[12] intercept   : AIC=-385.056, Time=0.32 sec
#  ARIMA(2,0,0)(1,1,1)[12] intercept   : AIC=-409.726, Time=1.30 sec
#  ARIMA(2,0,0)(0,1,2)[12] intercept   : AIC=-410.433, Time=1.44 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=-405.874, Time=1.01 sec
#  ARIMA(2,0,0)(1,1,2)[12] intercept   : AIC=-408.719, Time=3.03 sec
#  ARIMA(3,0,0)(0,1,1)[12] intercept   : AIC=-410.658, Time=1.33 sec
#  ARIMA(3,0,1)(0,1,1)[12] intercept   : AIC=-408.760, Time=1.46 sec
#  ARIMA(2,0,0)(0,1,1)[12]             : AIC=-405.926, Time=0.76 sec
#
# Best model:  ARIMA(2,0,0)(0,1,1)[12] intercept
# Total fit time: 48.791 seconds
# -412.37936788436974

# %%
predictions = model.predict(20)
print('MSE:', mean_squared_error(test.values, predictions))
print('RMSE:', np.sqrt(mean_squared_error(test.values, predictions)))
print('MAE:', mean_absolute_error(test.values, predictions))
# Out:
# MSE: 0.0014484523971820997
# RMSE: 0.03805853908365506
# MAE: 0.02700906511382741

# %%
print(model.summary())
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  124
# Model:             SARIMAX(2, 0, 0)x(0, 1, [1], 12)   Log Likelihood                 211.190
# Date:                              Tue, 26 Jan 2021   AIC                           -412.379
# Time:                                      16:37:44   BIC                           -398.787
# Sample:                                           0   HQIC                          -406.864
#                                               - 124
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0190      0.010      1.963      0.050    2.63e-05       0.038
# ar.L1          0.6087      0.086      7.090      0.000       0.440       0.777
# ar.L2          0.2355      0.090      2.623      0.009       0.060       0.412
# ma.S.L12      -0.5618      0.116     -4.825      0.000      -0.790      -0.334
# sigma2         0.0013      0.000      7.750      0.000       0.001       0.002
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 4.77
# Prob(Q):                              0.99   Prob(JB):                         0.09
# Heteroskedasticity (H):               0.41   Skew:                             0.09
# Prob(H) (two-sided):                  0.01   Kurtosis:                         3.99
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ## 7. Representa en una gráfica los datos de test y tus predicciones.

# %%
plt.plot(test.values)
plt.plot(predictions, color='red');

# %%
predictions2 = pd.Series(predictions)
predictions2.index = test.index

# %%
plt.rcParams["figure.figsize"] = [15, 7]
plt.plot(train, label='Train ')
plt.plot(test, label='Test ')
plt.plot(predictions2, label=f'Predicted with m={str(12)} ')
plt.legend(loc='best');

# %% [markdown]
# ## 8. Prueba otros modelos, a ver qué performance presentan.

# %%
for i in range(12, 0, -1):
    df['t-'+str(i)] = df['value'].shift(i)
df.head()
# Out:
#                value  t-12  t-11  t-10  t-9  t-8  t-7  t-6  t-5       t-4  \
# date
# 1949-01-01  4.718499   NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 1949-02-01  4.770685   NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 1949-03-01  4.882802   NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 1949-04-01  4.859812   NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 1949-05-01  4.795791   NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN  4.718499
#
#                  t-3       t-2       t-1
# date
# 1949-01-01       NaN       NaN       NaN
# 1949-02-01       NaN       NaN  4.718499
# 1949-03-01       NaN  4.718499  4.770685
# 1949-04-01  4.718499  4.770685  4.882802
# 1949-05-01  4.770685  4.882802  4.859812

# %%
df.dropna(inplace=True)
df.head()
# Out:
#                value      t-12      t-11      t-10       t-9       t-8  \
# date
# 1950-01-01  4.744932  4.718499  4.770685  4.882802  4.859812  4.795791
# 1950-02-01  4.836282  4.770685  4.882802  4.859812  4.795791  4.905275
# 1950-03-01  4.948760  4.882802  4.859812  4.795791  4.905275  4.997212
# 1950-04-01  4.905275  4.859812  4.795791  4.905275  4.997212  4.997212
# 1950-05-01  4.828314  4.795791  4.905275  4.997212  4.997212  4.912655
#
#                  t-7       t-6       t-5       t-4       t-3       t-2  \
# date
# 1950-01-01  4.905275  4.997212  4.997212  4.912655  4.779123  4.644391
# 1950-02-01  4.997212  4.997212  4.912655  4.779123  4.644391  4.770685
# 1950-03-01  4.997212  4.912655  4.779123  4.644391  4.770685  4.744932
# 1950-04-01  4.912655  4.779123  4.644391  4.770685  4.744932  4.836282
# 1950-05-01  4.779123  4.644391  4.770685  4.744932  4.836282  4.948760
#
#                  t-1
# date
# 1950-01-01  4.770685
# 1950-02-01  4.744932
# 1950-03-01  4.836282
# 1950-04-01  4.948760
# 1950-05-01  4.905275

# %%
len(df)
# Out:
# 132

# %%
X = df.iloc[:, 1:].values
Y = df.iloc[:, 0].values

X_train = X[:-20]
X_test = X[-20:]

y_train = Y[:-20]
y_test = Y[-20:]
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (112, 12)
# (20, 12)
# (112,)
# (20,)

# %%
from sklearn.tree import DecisionTreeRegressor

tree = DecisionTreeRegressor()

tree.fit(X_train, y_train)

print('MSE:', mean_squared_error(tree.predict(X_test), y_test))
print('RMSE:', np.sqrt(mean_squared_error(tree.predict(X_test), y_test)))
print('MAE:', mean_absolute_error(tree.predict(X_test), y_test))
# Out:
# MSE: 0.009566197480872193
# RMSE: 0.09780693984003483
# MAE: 0.07511556776584269

# %%
def prediction(model, x_test):
    preds = x_test[0]
    preds_out = []
    for i in range(len(x_test)):
        pred = model.predict([preds])[0]
        preds_out.append(pred)

        preds2 = np.array([preds[1:]])

        preds = np.c_[preds2, np.array([pred])][0]
    return preds_out

# %%
'''
Cuidado con los X_test, que se tienen que ir actualizando con cada prediccion
ya que utiliza
'''
# Out:
# '\nCuidado con los X_test, que se tienen que ir actualizando con cada prediccion\nya que utiliza\n'
